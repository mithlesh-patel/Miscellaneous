# %%
## pip install tika
 
# import parser from tika

from tika import parser
 
# get a sample pdf
parsedPDF = parser.from_file("/Users/mithleshpatel/Documents/BillDesk - All Your Payments.pdf")
 
# print parsed PDF data
print parsedPDF
print parsedPDF.viewkeys()
print parsedPDF["metadata"]
print parsedPDF["content"]
# Out:
# 2017-12-24 16:02:00,010 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.15/tika-server-1.15.jar.md5 to /var/folders/wp/hfcgvk452y17ng5mxps6kfhh0000gp/T/tika-server.jar.md5.
# 2017-12-24 16:02:00,401 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.15/tika-server-1.15.jar to /var/folders/wp/hfcgvk452y17ng5mxps6kfhh0000gp/T/tika-server.jar.
# {'content': u'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n5/27/2017 BillDesk - All Your Payments. Single Location\n\nhttps://www.billdesk.com/pgidsk/pgmerc/LICReceipt.jsp 1/1\n\nPAYMENT\xa0\xad\xa0ACKNOWLEDGEMENT\n\nTransaction\xa0Details\n\n\u2713\xa0PAYMENT\xa0SUCCESSFUL\nThe\xa0premium\xa0payment\xa0towards\xa0your\xa0LIC\xa0policy\xa0was\xa0successfully\xa0processed\xa0with\xa0the\xa0transaction\xa0details\xa0as\xa0shown\xa0below.\xa0You\xa0will\xa0receive\xa0the\xa0LIC\xa0Premium\nPayment\xa0Receipt\xa0to\xa0your\xa0email\xa0ID\xa0within\xa0the\xa0next\xa048\xa0hours.\xa0\xa0\n\nPlease\xa0contact\xa0bo_eps1@licindia.com\xa0(mailto:bo_eps1@licindia.com)\xa0for\xa0any\xa0queries\xa0pertaining\xa0to\xa0the\xa0transaction\xa0and\xa0quote\xa0your\xa0Payment\xa0ID\xa0shown\xa0below.\n\nPayment\xa0ID IICI5393270983\n\nLIC\xa0Order\xa0Number 02528284\n\nPayment\xa0Date\xa0and\xa0Time 27\xad05\xad2017\xa023:26:21\n\nPayment\xa0Through ICICI\xa0NetBanking\n\nPayment\xa0Amount(Rs.) 6125.00\n\n\xa0\n\nmailto:bo_eps1@licindia.com\n\n', 'metadata': {u'access_permission:can_modify': u'true', u'access_permission:extract_content': u'true', u'producer': u'Skia/PDF m58', u'meta:save-date': u'2017-05-27T17:57:54Z', u'Last-Modified': u'2017-05-27T17:57:54Z', u'xmp:CreatorTool': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36', u'dcterms:created': u'2017-05-27T17:57:54Z', u'access_permission:can_print': u'true', u'X-Parsed-By': [u'org.apache.tika.parser.DefaultParser', u'org.apache.tika.parser.pdf.PDFParser'], u'pdf:docinfo:created': u'2017-05-27T17:57:54Z', u'access_permission:extract_for_accessibility': u'true', u'access_permission:fill_in_form': u'true', u'pdf:encrypted': u'false', u'pdf:docinfo:producer': u'Skia/PDF m58', u'dc:format': u'application/pdf; version=1.4', u'access_permission:can_print_degraded': u'true', u'Creation-Date': u'2017-05-27T17:57:54Z', u'pdf:docinfo:creator_tool': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36', u'pdf:docinfo:modified': u'2017-05-27T17:57:54Z', u'access_permission:assemble_document': u'true', u'Last-Save-Date': u'2017-05-27T17:57:54Z', u'X-TIKA:parse_time_millis': u'534', u'date': u'2017-05-27T17:57:54Z', u'created': u'Sat May 27 18:57:54 BST 2017', u'modified': u'2017-05-27T17:57:54Z', u'meta:creation-date': u'2017-05-27T17:57:54Z', u'access_permission:modify_annotations': u'true', u'pdf:PDFVersion': u'1.4', u'xmpTPg:NPages': u'1', u'dcterms:modified': u'2017-05-27T17:57:54Z', u'Content-Type': u'application/pdf'}}
# dict_keys(['content', 'metadata'])
# {u'access_permission:can_modify': u'true', u'access_permission:extract_content': u'true', u'producer': u'Skia/PDF m58', u'meta:save-date': u'2017-05-27T17:57:54Z', u'Last-Modified': u'2017-05-27T17:57:54Z', u'xmp:CreatorTool': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36', u'dcterms:created': u'2017-05-27T17:57:54Z', u'access_permission:can_print': u'true', u'X-Parsed-By': [u'org.apache.tika.parser.DefaultParser', u'org.apache.tika.parser.pdf.PDFParser'], u'pdf:docinfo:created': u'2017-05-27T17:57:54Z', u'access_permission:extract_for_accessibility': u'true', u'access_permission:fill_in_form': u'true', u'pdf:encrypted': u'false', u'pdf:docinfo:producer': u'Skia/PDF m58', u'dc:format': u'application/pdf; version=1.4', u'access_permission:can_print_degraded': u'true', u'Creation-Date': u'2017-05-27T17:57:54Z', u'pdf:docinfo:creator_tool': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36', u'pdf:docinfo:modified': u'2017-05-27T17:57:54Z', u'access_permission:assemble_document': u'true', u'Last-Save-Date': u'2017-05-27T17:57:54Z', u'X-TIKA:parse_time_millis': u'534', u'date': u'2017-05-27T17:57:54Z', u'created': u'Sat May 27 18:57:54 BST 2017', u'modified': u'2017-05-27T17:57:54Z', u'meta:creation-date': u'2017-05-27T17:57:54Z', u'access_permission:modify_annotations': u'true', u'pdf:PDFVersion': u'1.4', u'xmpTPg:NPages': u'1', u'dcterms:modified': u'2017-05-27T17:57:54Z', u'Content-Type': u'application/pdf'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5/27/2017 BillDesk - All Your Payments. Single Location
#
# https://www.billdesk.com/pgidsk/pgmerc/LICReceipt.jsp 1/1
#
# PAYMENT ­ ACKNOWLEDGEMENT
#
# Transaction Details
#
# ✓ PAYMENT SUCCESSFUL
# The premium payment towards your LIC policy was successfully processed with the transaction details as shown below. You will receive the LIC Premium
# Payment Receipt to your email ID within the next 48 hours.
#
# Please contact bo_eps1@licindia.com (mailto:bo_eps1@licindia.com) for any queries pertaining to the transaction and quote your Payment ID shown below.
#
# Payment ID IICI5393270983
#
# LIC Order Number 02528284
#
# Payment Date and Time 27­05­2017 23:26:21
#
# Payment Through ICICI NetBanking
#
# Payment Amount(Rs.) 6125.00
#
#
#
# mailto:bo_eps1@licindia.com

# %%
print parsedPDF["content"]
# Out:
# 5/27/2017 BillDesk - All Your Payments. Single Location
#
# https://www.billdesk.com/pgidsk/pgmerc/LICReceipt.jsp 1/1
#
# PAYMENT ­ ACKNOWLEDGEMENT
#
# Transaction Details
#
# ✓ PAYMENT SUCCESSFUL
# The premium payment towards your LIC policy was successfully processed with the transaction details as shown below. You will receive the LIC Premium
# Payment Receipt to your email ID within the next 48 hours.
#
# Please contact bo_eps1@licindia.com (mailto:bo_eps1@licindia.com) for any queries pertaining to the transaction and quote your Payment ID shown below.
#
# Payment ID IICI5393270983
#
# LIC Order Number 02528284
#
# Payment Date and Time 27­05­2017 23:26:21
#
# Payment Through ICICI NetBanking
#
# Payment Amount(Rs.) 6125.00
#
#
#
# mailto:bo_eps1@licindia.com
