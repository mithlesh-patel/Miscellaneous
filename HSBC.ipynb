# %%
## pip install tika
 
# import parser from tika

from tika import parser
import re
# get a sample pdf
parsedPDF = parser.from_file("/Users/mithleshpatel/Documents/ImpDocs/HSBC Statements/statements-20.pdf")
 
# print parsed PDF data
#print parsedPDF
#print parsedPDF.viewkeys()
#print parsedPDF["metadata"]
content = parsedPDF["content"]

# %%
contents = content.splitlines()
regex = r'^[+-]{0,1}((\d*\.)*)+$'

# %%
rows=[]
i=0
for text in contents:
    if text <> '':
        text_array=text.split(' ')
        for e in text_array:
            d = re.match(regex, e)
            if d <> 'None':
                if print i
    i+=1
# Out:
# CS - VICTORI@17:04 60.00 2,291.58
# HSBC Bank plc
# HSBC Bank plc
# Registered in England and Wales with registration number 14259
# Registered in England and Wales with registration number 14259
# Credit Interest is calculated daily on the cleared credit
# balance and is paid monthly if applicable (this is not paid on all
# accounts, eg, Basic Bank Account, Bank Account and HSBC
# Advance). For personal current accounts (excluding Premier
# and Jade by HSBC Premier) overdraft interest is only charged
# on arranged overdrawn balances. Debit interest is calculated
# daily on the cleared debit balance of your account, it accrues
# during your charging cycle (usually monthly) and is deducted
# Effective from 1 August 2017
# 1. Each current account will set a monthly maximum
# 1. Each current account will set a monthly maximum
# (a) going overdrawn when you have not arranged an
# (b) going over/past your arranged overdraft limit (if you
# have one).
# 2. This cap covers any:
# ...

# %%
rows
# Out:
# [u'CS - VICTORI@17:04 60.00 2,291.58',
#  u'HSBC Bank plc  ',
#  u'Registered in England and Wales with registration number 14259  ',
#  u'Credit Interest is calculated daily on the cleared credit ',
#  u'balance and is paid monthly if applicable (this is not paid on all ',
#  u'accounts, eg, Basic Bank Account, Bank Account and HSBC ',
#  u'Advance). For personal current accounts (excluding Premier ',
#  u'and Jade by HSBC Premier) overdraft interest is only charged ',
#  u'on arranged overdrawn balances. Debit interest is calculated ',
#  u'daily on the cleared debit balance of your account, it accrues ',
#  u'during your charging cycle (usually monthly) and is deducted ',
#  u'Effective from 1 August 2017 ',
#  u'1. Each current account will set a monthly maximum ',
#  u'(a) going overdrawn when you have not arranged an ',
#  u'(b) going over/past your arranged overdraft limit (if you ',
#  u'have one). ',
#  u'2. This cap covers any:',
# ...
